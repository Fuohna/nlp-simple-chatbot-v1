# %%
# !pip install -q -U "tensorflow-text==2.8.*"
# !pip install -q -U "tensorflow==2.8.*"

# %%
import pandas as pd
import json
import string
import tensorflow as tf
from tensorflow import keras
import tensorflow_text as tf_text
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Preprocessing

# %%
leyzer_dev_url = 'https://raw.githubusercontent.com/cartesinus/leyzer/master/corpora/0.1.0/leyzer-dev-en-US-0.1.0.tsv'
leyzer_dev_df = pd.DataFrame(pd.read_csv(leyzer_dev_url, sep='\t'))

# %%
leyzer_df = leyzer_dev_df
leyzer_df.drop(["bio"], axis = 1, inplace = True)
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0                      switch the air conditioning off
# 1                                      turn the ac off
# 2                                 switch on the aircon
# 3                                   turn the aircon on
# 4    change the minimum and maximum temperatures on...
# ..                                                 ...
# 373  show a video from niki and gabi matching seinf...
# 374  show me a video from cineamasin matching lipst...
# 375  show me a videos published by wwe matching gre...
# 376  notify me when there is new video from youtube...
# 377  notify me when there is new video from youtube...
#
# [378 rows x 3 columns]

# %%
leyzer_df['utterance'] = leyzer_df['utterance'].apply(lambda sequence: [ltrs.lower() for ltrs in sequence if ltrs not in string.punctuation])
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0    [s, w, i, t, c, h,  , t, h, e,  , a, i, r,  , ...
# 1        [t, u, r, n,  , t, h, e,  , a, c,  , o, f, f]
# 2    [s, w, i, t, c, h,  , o, n,  , t, h, e,  , a, ...
# 3    [t, u, r, n,  , t, h, e,  , a, i, r, c, o, n, ...
# 4    [c, h, a, n, g, e,  , t, h, e,  , m, i, n, i, ...
# ..                                                 ...
# 373  [s, h, o, w,  , a,  , v, i, d, e, o,  , f, r, ...
# 374  [s, h, o, w,  , m, e,  , a,  , v, i, d, e, o, ...
# 375  [s, h, o, w,  , m, e,  , a,  , v, i, d, e, o, ...
# 376  [n, o, t, i, f, y,  , m, e,  , w, h, e, n,  , ...
# 377  [n, o, t, i, f, y,  , m, e,  , w, h, e, n,  , ...
#
# [378 rows x 3 columns]

# %%
leyzer_df['utterance'] = leyzer_df['utterance'].apply(lambda word: ''.join(word))
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0                      switch the air conditioning off
# 1                                      turn the ac off
# 2                                 switch on the aircon
# 3                                   turn the aircon on
# 4    change the minimum and maximum temperatures on...
# ..                                                 ...
# 373  show a video from niki and gabi matching seinf...
# 374  show me a video from cineamasin matching lipst...
# 375  show me a videos published by wwe matching gre...
# 376  notify me when there is new video from youtube...
# 377  notify me when there is new video from youtube...
#
# [378 rows x 3 columns]

# %%
from nltk.tokenize import word_tokenize 
leyzer_df['utterance'] = leyzer_df['utterance'].apply(lambda sent: word_tokenize(sent))
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0                [switch, the, air, conditioning, off]
# 1                                 [turn, the, ac, off]
# 2                            [switch, on, the, aircon]
# 3                              [turn, the, aircon, on]
# 4    [change, the, minimum, and, maximum, temperatu...
# ..                                                 ...
# 373  [show, a, video, from, niki, and, gabi, matchi...
# 374  [show, me, a, video, from, cineamasin, matchin...
# 375  [show, me, a, videos, published, by, wwe, matc...
# 376  [notify, me, when, there, is, new, video, from...
# 377  [notify, me, when, there, is, new, video, from...
#
# [378 rows x 3 columns]

# %%
col = leyzer_df[['intent']]
print("Total number of intents:", len(col.intent.unique()))
# print(col.intent.unique())
# Out:
# Total number of intents: 178

# %%
leyzer_test_df = pd.DataFrame(pd.read_csv("https://raw.githubusercontent.com/cartesinus/leyzer/master/corpora/0.1.0/leyzer-test-en-US-0.1.0.tsv", sep="\t"))
print(len(leyzer_test_df[['intent']].intent.unique()))
# print(leyzer_test_df[['intent']].intent.unique())
# Out:
# 154

# %%
tokenizer = Tokenizer(1000)
tokenizer.fit_on_texts(leyzer_df['utterance'])
train = tokenizer.texts_to_sequences(leyzer_df['utterance'])
print(train)
features = pad_sequences(train)
print(len(features[0]))
# Out:
# [[118, 4, 173, 174, 119], [120, 4, 277, 119], [118, 1, 4, 175], [120, 4, 175, 1], [56, 4, 176, 14, 177, 178, 1, 3, 101], [57, 57, 3, 101, 2, 278, 143], [57, 4, 81, 2, 279, 280, 281, 1, 3, 282, 101], [57, 4, 283, 81, 2, 284, 143, 1, 3, 101, 14, 4, 285, 2, 286, 143], [56, 4, 176, 14, 177, 178, 1, 3, 179, 144, 101], [9, 4, 180, 181], [58, 4, 180, 181], [121, 81, 74, 16, 82, 11, 102, 182, 2, 3, 287, 288], [121, 81, 59, 52, 11, 102, 182, 
#  116 116 165 165 169 169 167 167 167 167 167 167 167 167 167 167 167 167
#  168 168 168 168 168 168 168 168 168 168 168 170 170 166 166 166  20  20
#   63  63  29 174 109 109 109 111 111 157 157 157 157 157 157 157  64 176
#   36  37 160 161 162 163 175 175 177 177  53 102 102 103 103 103  96  96
#   95  97  98  65 100 100 100  85  86  21   9   9   9   9  80  33  33 101
#  101  89  91  87  59  93  60  60  88  88  90  90  92  92  92  94  94  99
#   99  66  27  27  27  27  27 127 126 156 143  26  26  28  28  28  45  49]

# %%
tokenizer.word_index
# Out:
# {'on': 1,
#  'to': 2,
#  'my': 3,
#  'the': 4,
#  'with': 5,
#  'a': 6,
#  'from': 7,
#  'of': 8,
#  'show': 9,
#  'me': 10,
#  'in': 11,
#  'new': 12,
#  'slack': 13,
#  'and': 14,
#  'number': 15,
#  'i': 16,
#  '555': 17,
#  'create': 18,
#  'contact': 19,
#  'spotify': 20,
#  'an': 21,
#  'for': 22,
#  'email': 23,
#  'playlist': 24,
#  'play': 25,
#  'open': 26,
#  'google': 27,
#  'emails': 28,
#  'post': 29,
#  'translation': 30,
#  'youtube': 31,
#  'at': 32,
#  'get': 33,
#  'send': 34,
#  'add': 35,
#  'as': 36,
#  'that': 37,
#  'message': 38,
#  'instagram': 39,
#  'restaurants': 40,
#  'contacts': 41,
#  'name': 42,
#  'track': 43,
#  'italian': 44,
#  'display': 45,
#  'translate': 46,
#  'french': 47,
#  'notify': 48,
#  '1': 49,
#  'this': 50,
#  'by': 51,
#  'it': 52,
#  'when': 53,
#  'picture': 54,
#  'english': 55,
#  'change': 56,
#  'set': 57,
#  'check': 58,
#  'is': 59,
#  'calendar': 60,
#  'using': 61,
#  'drive': 62,
#  'pictures': 63,
#  'polish': 64,
#  'twitter': 65,
#  'call': 66,
#  'subject': 67,
#  'facebook': 68,
#  'channel': 69,
#  'speaker': 70,
#  'song': 71,
#  'tweets': 72,
#  'matching': 73,
#  'do': 74,
#  'location': 75,
#  'phone': 76,
#  'find': 77,
#  'list': 78,
#  'saying': 79,
#  'language': 80,
#  'temperature': 81,
#  'have': 82,
#  'begins': 83,
#  '803': 84,
#  'work': 85,
#  'gmail': 86,
#  'received': 87,
#  'last': 88,
#  'steps': 89,
#  'fitbit': 90,
#  'files': 91,
#  'save': 92,
#  'around': 93,
#  'video': 94,
#  '1st': 95,
#  '202': 96,
#  'make': 97,
#  'how': 98,
#  'german': 99,
#  'weather': 100,
#  'thermostat': 101,
#  'here': 102,
#  'event': 103,
#  'containing': 104,
#  'upload': 105,
#  'caption': 106,
#  'january': 107,
#  'hashtag': 108,
#  'messages': 109,
#  'you': 110,
#  'current': 111,
#  'spanish': 112,
#  'search': 113,
#  'images': 114,
#  'page': 115,
#  'near': 116,
#  'channels': 117,
#  'switch': 118,
#  'off': 119,
#  'turn': 120,
#  'what': 121,
#  'called': 122,
#  'meeting': 123,
#  'edition': 124,
#  'home': 125,
#  '303': 126,
#  'private': 127,
#  'taken': 128,
#  'named': 129,
#  'recent': 130,
#  'news': 131,
#  'services': 132,
#  'sms': 133,
#  'app': 134,
#  'about': 135,
#  'tomorrow': 136,
#  'volume': 137,
#  'sunrise': 138,
#  '3': 139,
#  'de': 140,
#  'deepl': 141,
#  'star': 142,
#  'degree': 143,
#  'room': 144,
#  'great': 145,
#  'not': 146,
#  'west': 147,
#  'inbox': 148,
#  'latest': 149,
#  'label': 150,
#  'music': 151,
#  'arrived': 152,
#  'forward': 153,
#  'one': 154,
#  'answer': 155,
#  'so': 156,
#  'now': 157,
#  'than': 158,
#  'time': 159,
#  'article': 160,
#  'please': 161,
#  's': 162,
#  'go': 163,
#  'un': 164,
#  'there': 165,
#  'sunset': 166,
#  'bing': 167,
#  'yelp': 168,
#  'reviewed': 169,
#  'least': 170,
#  'people': 171,
#  'videos': 172,
#  'air': 173,
#  'conditioning': 174,
#  'aircon': 175,
#  'minimum': 176,
#  'maximum': 177,
#  'temperatures': 178,
#  'living': 179,
#  'humidity': 180,
#  'level': 181,
#  'according': 182,
#  'sensor': 183,
#  'whats': 184,
#  'schedule': 185,
#  'july': 186,
#  'appointment': 187,
#  '0121': 188,
#  '0122': 189,
#  '615': 190,
#  '0179': 191,
#  'sport': 192,
#  'holidays': 193,
#  '30': 194,
#  'minutes': 195,
#  'information': 196,
#  'back': 197,
#  'their': 198,
#  'increase': 199,
#  'more': 200,
#  'tired': 201,
#  'today': 202,
#  'am': 203,
#  'dad': 204,
#  'wwwtinyurlcomvmkgtf9': 205,
#  'photos': 206,
#  'step': 207,
#  'count': 208,
#  'weight': 209,
#  'file': 210,
#  'were': 211,
#  '10': 212,
#  'filter': 213,
#  'took': 214,
#  'tagged': 215,
#  'photo': 216,
#  'gallery': 217,
#  'nyt': 218,
#  'section': 219,
#  'times': 220,
#  '34': 221,
#  '678': 222,
#  '09': 223,
#  '94': 224,
#  'text': 225,
#  'launch': 226,
#  'class': 227,
#  'physics': 228,
#  'speculate': 229,
#  'transportation': 230,
#  'topic': 231,
#  'party': 232,
#  'possibilities': 233,
#  'decrease': 234,
#  '50': 235,
#  'some': 236,
#  'choo': 237,
#  'repeat': 238,
#  'next': 239,
#  'skip': 240,
#  'rock': 241,
#  'piano': 242,
#  'currently': 243,
#  'playing': 244,
#  'your': 245,
#  'coffee': 246,
#  'danceability': 247,
#  'default': 248,
#  'say': 249,
#  'lost': 250,
#  'yandex': 251,
#  'faire': 252,
#  'le': 253,
#  'microsoft': 254,
#  'sentence': 255,
#  'written': 256,
#  'be': 257,
#  'direct': 258,
#  'think': 259,
#  'moon': 260,
#  'phase': 261,
#  'date': 262,
#  'duckduckgo': 263,
#  '800': 264,
#  'wikipedia': 265,
#  'wiki': 266,
#  'scroll': 267,
#  'portuguese': 268,
#  'item': 269,
#  'contents': 270,
#  'nearby': 271,
#  '1000': 272,
#  'look': 273,
#  'follow': 274,
#  'rockabye': 275,
#  'baby': 276,
#  'ac': 277,
#  '25': 278,
#  '80': 279,
#  'degrees': 280,
#  'fahrenheit': 281,
#  'hall': 282,
#  'low': 283,
#  '23': 284,
#  'high': 285,
#  '29': 286,
#  'cooling': 287,
#  'system': 288,
#  'kitchen': 289,
#  'does': 290,
#  'indoor': 291,
#  'thursday': 292,
#  '13th': 293,
#  'march': 294,
#  '1on1': 295,
#  'neighborhood': 296,
#  'council': 297,
#  'streets': 298,
#  'may': 299,
#  'library': 300,
#  'lab': 301,
#  'wawarsing': 302,
#  'louisville': 303,
#  'ouray': 304,
#  'johns': 305,
#  'island': 306,
#  'info': 307,
#  'miquela': 308,
#  'chastity': 309,
#  'hadria': 310,
#  'quintina': 311,
#  '0199': 312,
#  'head': 313,
#  'helsayahoocom': 314,
#  'gabriellwalliwenrondevelopment': 315,
#  'karinlepineschwabcom': 316,
#  'plantagenet': 317,
#  'bernita': 318,
#  'marchris': 319,
#  'robinson': 320,
#  'lenna': 321,
#  '0176': 322,
#  'umeh': 323,
#  '860': 324,
#  '0190': 325,
#  'glennis': 326,
#  '602': 327,
#  'marty': 328,
#  'chrisman': 329,
#  '0193': 330,
#  'claude': 331,
#  '0198': 332,
#  'thane': 333,
#  '0178': 334,
#  'linnell': 335,
#  '0194': 336,
#  'chester': 337,
#  '0144': 338,
#  'joana': 339,
#  '605': 340,
#  '0109': 341,
#  'bertina': 342,
#  '0116': 343,
#  'guinevere': 344,
#  '502': 345,
#  'nike': 346,
#  'jennifer': 347,
#  'walker': 348,
#  '0171': 349,
#  'vicki': 350,
#  '0106': 351,
#  'kass': 352,
#  '0114': 353,
#  '0143': 354,
#  '0174': 355,
#  '0107': 356,
#  'murkyoutlookcom': 357,
#  'ermakurysgedazcom': 358,
#  '0148': 359,
#  'pakkyahoogroupscom': 360,
#  'edythekpmgcom': 361,
#  'malissiaedelmancom': 362,
#  'enronenvironmentalenroncom': 363,
#  'got': 364,
#  'suzettecandidaoutlookcom': 365,
#  'emaleeoutlookcom': 366,
#  'shelbygaylagmailcom': 367,
#  'corieprotoncom': 368,
#  'labelled': 369,
#  'offers': 370,
#  '15': 371,
#  'tuesday': 372,
#  'requests': 373,
#  'original': 374,
#  'advantage': 375,
#  'unimportant': 376,
#  'virginiaoutlookcom': 377,
#  're': 378,
#  'night': 379,
#  'thanks': 380,
#  'getting': 381,
#  'calvert': 382,
#  'axia': 383,
#  'energy': 384,
#  'lp': 385,
#  'sorry': 386,
#  'thought': 387,
#  'we': 388,
#  'had': 389,
#  'until': 390,
#  'end': 391,
#  'week': 392,
#  'denys': 393,
#  'free': 394,
#  'lunch': 395,
#  'friday': 396,
#  'improve': 397,
#  'career': 398,
#  'prospects': 399,
#  'value': 400,
#  'timothyjdetmeringenroncom': 401,
#  'proposed': 402,
#  'edits': 403,
#  'nda': 404,
#  'advent': 405,
#  'international': 406,
#  'dolphin': 407,
#  'communications': 408,
#  'koralcpuccagov': 409,
#  'edison': 410,
#  'advice': 411,
#  'letter': 412,
#  'faydrahotmailcom': 413,
#  'thing': 414,
#  'laura': 415,
#  'schwartz': 416,
#  'draft': 417,
#  'kens': 418,
#  'itinerary': 419,
#  'darran': 420,
#  'binns': 421,
#  'jonishotmailcom': 422,
#  'juta': 423,
#  'ina': 424,
#  'reply': 425,
#  'johaasberkeleyedu': 426,
#  'happy': 427,
#  'right': 428,
#  'put': 429,
#  'album': 430,
#  'counter': 431,
#  '15022020': 432,
#  'body': 433,
#  'measurements': 434,
#  'note': 435,
#  'if': 436,
#  'goes': 437,
#  'over': 438,
#  '60': 439,
#  'kg': 440,
#  'type': 441,
#  'mp3': 442,
#  'starred': 443,
#  'modified': 444,
#  'larger': 445,
#  '500': 446,
#  'kb': 447,
#  'invoice': 448,
#  'created': 449,
#  'most': 450,
#  'recently': 451,
#  'reverse': 452,
#  'alphabetical': 453,
#  'order': 454,
#  'newfile': 455,
#  'share': 456,
#  'vegetarian': 457,
#  'recipies': 458,
#  'marylougmailcom': 459,
#  '2': 460,
#  'account': 461,
#  'lark': 462,
#  'aden': 463,
#  'applied': 464,
#  'berlin': 465,
#  'douds': 466,
#  'north': 467,
#  'tonawanda': 468,
#  'gps': 469,
#  'tag': 470,
#  'searsboro': 471,
#  'fashionphoto': 472,
#  'all': 473,
#  'traer': 474,
#  'february': 475,
#  'collage': 476,
#  '16': 477,
#  'take': 478,
#  'adding': 479,
#  'fitspo': 480,
#  'magazine': 481,
#  'updates': 482,
#  'ny': 483,
#  'celebrity': 484,
#  'publishes': 485,
#  'dial': 486,
#  '22': 487,
#  '590': 488,
#  '01': 489,
#  '45': 490,
#  '00': 491,
#  '589': 492,
#  '999': 493,
#  '000': 494,
#  'emergency': 495,
#  'valli': 496,
#  'simonetta': 497,
#  'tedra': 498,
#  'renate': 499,
#  'maiga': 500,
#  'luella': 501,
#  'helli': 502,
#  'laurence': 503,
#  'dickon': 504,
#  'dhookfin': 505,
#  'carroll': 506,
#  'hour': 507,
#  'let': 508,
#  'know': 509,
#  'phillip': 510,
#  'mercer': 511,
#  'o': 512,
#  'job': 513,
#  'site': 514,
#  'wayfaircom': 515,
#  'prepares': 516,
#  'monday': 517,
#  'can': 518,
#  'anyone': 519,
#  'print': 520,
#  'concerned': 521,
#  'terms': 522,
#  'deal': 523,
#  'undisclosed': 524,
#  'steve': 525,
#  'lingeman': 526,
#  'power': 527,
#  'plants': 528,
#  'encourage': 529,
#  'consumption': 530,
#  'trader': 531,
#  'editorial': 532,
#  'meetings': 533,
#  'minimal': 534,
#  'guidance': 535,
#  'or': 536,
#  'supervision': 537,
#  'northeast': 538,
#  'independent': 539,
#  'transmission': 540,
#  'company': 541,
#  'proponents': 542,
#  'purpose': 543,
#  'scrum': 544,
#  'mona': 545,
#  'birthday': 546,
#  'helicopters': 547,
#  'confidentially': 548,
#  'minal': 549,
#  'cents': 550,
#  'shorturlatb8sezev': 551,
#  'wwwtinyurlcomvfizsay': 552,
#  'cuttlypg2yidh': 553,
#  'louder': 554,
#  '5': 555,
#  'reduce': 556,
#  'percent': 557,
#  'silence': 558,
#  'unmute': 559,
#  'use': 560,
#  'arrow': 561,
#  'our': 562,
#  'youth': 563,
#  'moscow': 564,
#  'trofea': 565,
#  'die': 566,
#  'tool': 567,
#  'norman': 568,
#  'fucking': 569,
#  'rockwell': 570,
#  'alex': 571,
#  'cameron': 572,
#  'venus': 573,
#  'furs': 574,
#  'thee': 575,
#  'oh': 576,
#  'sees': 577,
#  'smile': 578,
#  'stamina': 579,
#  'andy': 580,
#  'stott': 581,
#  'careful': 582,
#  'return': 583,
#  'center': 584,
#  'unknown': 585,
#  'mortal': 586,
#  'orchestra': 587,
#  'pause': 588,
#  'previous': 589,
#  'modern': 590,
#  'chill': 591,
#  'study': 592,
#  'undercurrents': 593,
#  'jukebox': 594,
#  'joint': 595,
#  'soulfull': 596,
#  'disco': 597,
#  'office': 598,
#  'stereo': 599,
#  'modernism': 600,
#  'custom': 601,
#  'concern': 602,
#  'feeling': 603,
#  'blue': 604,
#  'fantas': 605,
#  'break': 606,
#  'past': 607,
#  'dreampop': 608,
#  'hit': 609,
#  'man': 610,
#  'fresh': 611,
#  'dance': 612,
#  'tracks': 613,
#  'desire': 614,
#  'essential': 615,
#  'ska': 616,
#  'girl': 617,
#  'basket': 618,
#  'fruits': 619,
#  'bach': 620,
#  'switched': 621,
#  'data': 622,
#  'horde': 623,
#  'workday': 624,
#  'soul': 625,
#  'sirens': 626,
#  'sweat': 627,
#  'heard': 628,
#  'dog': 629,
#  'peaceful': 630,
#  'fear': 631,
#  'inoculum': 632,
#  'pure': 633,
#  'roll': 634,
#  'road': 635,
#  'trip': 636,
#  'tokyo': 637,
#  'legendary': 638,
#  'yoga': 639,
#  'seconds': 640,
#  'shuffle': 641,
#  'danceable': 642,
#  'dancey': 643,
#  'output': 644,
#  'source': 645,
#  'hawaiian': 646,
#  'input': 647,
#  'hindi': 648,
#  'anything': 649,
#  'quieter': 650,
#  'bag': 651,
#  'much': 652,
#  'into': 653,
#  'finish': 654,
#  'saturday': 655,
#  'thai': 656,
#  'speak': 657,
#  'zakaz': 658,
#  'parkowania': 659,
#  'ich': 660,
#  'heiße': 661,
#  'karl': 662,
#  'no': 663,
#  'lo': 664,
#  'quiero': 665,
#  'sera': 666,
#  'demi': 667,
#  'silvousplaît': 668,
#  'someone': 669,
#  'who': 670,
#  'speaks': 671,
#  'las': 672,
#  'che': 673,
#  'cosè': 674,
#  'zachód': 675,
#  'dónde': 676,
#  'puedo': 677,
#  'obtener': 678,
#  'talón': 679,
#  'viajero': 680,
#  'cambiado': 681,
#  'fais': 682,
#  'beaux': 683,
#  'reves': 684,
#  'youre': 685,
#  'welcome': 686,
#  'nie': 687,
#  'mówię': 688,
#  'po': 689,
#  'polsku': 690,
#  'märz': 691,
#  'venerdì': 692,
#  'half': 693,
#  'liter': 694,
#  'lipiec': 695,
#  'aceptan': 696,
#  'tarjetas': 697,
#  'crédito': 698,
#  'où': 699,
#  'puisje': 700,
#  'kurczaka': 701,
#  'cuando': 702,
#  'es': 703,
#  'la': 704,
#  'hora': 705,
#  'cerrar': 706,
#  'à': 707,
#  'quelle': 708,
#  'heure': 709,
#  'fermezvous': 710,
#  'russian': 711,
#  'ho': 712,
#  'una': 713,
#  'domanda': 714,
#  'bier': 715,
#  'pouvezvous': 716,
#  'sur': 717,
#  'travelers': 718,
#  'chèque': 719,
#  'adiós': 720,
#  'detect': 721,
#  'mille': 722,
#  'made': 723,
#  'follower': 724,
#  'myntmag': 725,
#  'stop': 726,
#  'following': 727,
#  'convalid1': 728,
#  'fondly': 729,
#  'two': 730,
#  'followers': 731,
#  'summerbabe16': 732,
#  'rip': 733,
#  'clevland': 734,
#  'valovanity': 735,
#  'omg': 736,
#  'its': 737,
#  'leaving': 738,
#  'jet': 739,
#  'plane': 740,
#  'salsa4change': 741,
#  'bloodymarytime': 742,
#  'dialoguesthatsux': 743,
#  'myweakness': 744,
#  'saintjohn': 745,
#  'weightwatchers': 746,
#  'crocsfeelgood01': 747,
#  'outside': 748,
#  'dakar': 749,
#  'barnsdall': 750,
#  'east': 751,
#  'fultonham': 752,
#  'dos': 753,
#  'rios': 754,
#  '7': 755,
#  'september': 756,
#  'jonas': 757,
#  'ridge': 758,
#  'lakes': 759,
#  'tangipahoa': 760,
#  'kinston': 761,
#  'pebble': 762,
#  'beach': 763,
#  'camp': 764,
#  'web': 765,
#  'pages': 766,
#  'progress': 767,
#  'book': 768,
#  'websites': 769,
#  'repackaging': 770,
#  'fan': 771,
#  'cast': 772,
#  'game': 773,
#  'thrones': 774,
#  'agario': 775,
#  'dollar': 776,
#  'shave': 777,
#  'club': 778,
#  'joker': 779,
#  'wallpaper': 780,
#  'cats': 781,
#  'reflection': 782,
#  'nebula': 783,
#  'size': 784,
#  'x': 785,
#  '600': 786,
#  'lebron': 787,
#  '11': 788,
#  'wider': 789,
#  'definition': 790,
#  'statue': 791,
#  'zeus': 792,
#  'olympia': 793,
#  'kanye': 794,
#  'art': 795,
#  'war': 796,
#  'down': 797,
#  'up': 798,
#  'download': 799,
#  'pdf': 800,
#  'random': 801,
#  'second': 802,
#  'tenth': 803,
#  'restaurant': 804,
#  'shop': 805,
#  '100': 806,
#  'kreuzberg': 807,
#  'still': 808,
#  'ravenden': 809,
#  'springs': 810,
#  'japanease': 811,
#  'food': 812,
#  'hanlontown': 813,
#  'leyden': 814,
#  'lorain': 815,
#  'county': 816,
#  'sushi': 817,
#  'nelsonia': 818,
#  'pizza': 819,
#  'evart': 820,
#  'schofield': 821,
#  'barracks': 822,
#  '4': 823,
#  'mount': 824,
#  'lemmon': 825,
#  'rating': 826,
#  'cincinnatus': 827,
#  'tokio': 828,
#  'inarajan': 829,
#  'mill': 830,
#  'run': 831,
#  'santa': 832,
#  'rita': 833,
#  'park': 834,
#  'jacksepticeye': 835,
#  'china': 836,
#  'crowded': 837,
#  'pics': 838,
#  '1995': 839,
#  'jeep': 840,
#  'radio': 841,
#  'repair': 842,
#  'unfreezing': 843,
#  'frozen': 844,
#  'pipes': 845,
#  'dubstep': 846,
#  'pewdiepie': 847,
#  'comedy': 848,
#  'subscribed': 849,
#  'taylor': 850,
#  'swift': 851,
#  'niki': 852,
#  'gabi': 853,
#  'seinfeld': 854,
#  'cineamasin': 855,
#  'lipstick': 856,
#  'published': 857,
#  'wwe': 858,
#  'gatsby': 859,
#  'unbox': 860,
#  'therapy': 861}

# %%
vocabulary = len(tokenizer.word_index)
print("Total numbers of vocabulary:", vocabulary)
# Out:
# Total numbers of vocabulary: 861

# %% [markdown]
# # Model
