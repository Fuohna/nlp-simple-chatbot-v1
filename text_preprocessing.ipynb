# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuohna/nlp-simple-chatbot-v1/blob/main/text_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
import string

# %% [markdown]
# # Preprocessing

# %%
leyzer_dev_url = 'https://raw.githubusercontent.com/cartesinus/leyzer/master/corpora/0.1.0/leyzer-dev-en-US-0.1.0.tsv'
leyzer_dev_df = pd.DataFrame(pd.read_csv(leyzer_dev_url, sep='\t'))

# %%
leyzer_df = leyzer_dev_df
leyzer_df.drop(["bio"], axis = 1, inplace = True)
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0                      switch the air conditioning off
# 1                                      turn the ac off
# 2                                 switch on the aircon
# 3                                   turn the aircon on
# 4    change the minimum and maximum temperatures on...
# ..                                                 ...
# 373  show a video from niki and gabi matching seinf...
# 374  show me a video from cineamasin matching lipst...
# 375  show me a videos published by wwe matching gre...
# 376  notify me when there is new video from youtube...
# 377  notify me when there is new video from youtube...
#
# [378 rows x 3 columns]

# %%
leyzer_df['utterance'] = leyzer_df['utterance'].apply(lambda sequence: [ltrs.lower() for ltrs in sequence if ltrs not in string.punctuation])
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0    [s, w, i, t, c, h,  , t, h, e,  , a, i, r,  , ...
# 1        [t, u, r, n,  , t, h, e,  , a, c,  , o, f, f]
# 2    [s, w, i, t, c, h,  , o, n,  , t, h, e,  , a, ...
# 3    [t, u, r, n,  , t, h, e,  , a, i, r, c, o, n, ...
# 4    [c, h, a, n, g, e,  , t, h, e,  , m, i, n, i, ...
# ..                                                 ...
# 373  [s, h, o, w,  , a,  , v, i, d, e, o,  , f, r, ...
# 374  [s, h, o, w,  , m, e,  , a,  , v, i, d, e, o, ...
# 375  [s, h, o, w,  , m, e,  , a,  , v, i, d, e, o, ...
# 376  [n, o, t, i, f, y,  , m, e,  , w, h, e, n,  , ...
# 377  [n, o, t, i, f, y,  , m, e,  , w, h, e, n,  , ...
#
# [378 rows x 3 columns]

# %%
leyzer_df['utterance'] = leyzer_df['utterance'].apply(lambda word: ''.join(word))
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0                      switch the air conditioning off
# 1                                      turn the ac off
# 2                                 switch on the aircon
# 3                                   turn the aircon on
# 4    change the minimum and maximum temperatures on...
# ..                                                 ...
# 373  show a video from niki and gabi matching seinf...
# 374  show me a video from cineamasin matching lipst...
# 375  show me a videos published by wwe matching gre...
# 376  notify me when there is new video from youtube...
# 377  notify me when there is new video from youtube...
#
# [378 rows x 3 columns]

# %%
import nltk 
nltk.download('punkt')
from nltk.tokenize import (word_tokenize, sent_tokenize)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
leyzer_df['utterance'] = leyzer_df['utterance'].apply(lambda sent: word_tokenize(sent))
leyzer_df
# Out:
#              domain                    intent  \
# 0    Airconditioner                   TurnOff
# 1    Airconditioner                   TurnOff
# 2    Airconditioner                    TurnOn
# 3    Airconditioner                    TurnOn
# 4    Airconditioner         ChangeTemperature
# ..              ...                       ...
# 373         Youtube        FindQueryOnChannel
# 374         Youtube        FindQueryOnChannel
# 375         Youtube        FindQueryOnChannel
# 376         Youtube  NotifyOnNewFromFollowing
# 377         Youtube      NotifyonNewOnChannel
#
#                                              utterance
# 0                [switch, the, air, conditioning, off]
# 1                                 [turn, the, ac, off]
# 2                            [switch, on, the, aircon]
# 3                              [turn, the, aircon, on]
# 4    [change, the, minimum, and, maximum, temperatu...
# ..                                                 ...
# 373  [show, a, video, from, niki, and, gabi, matchi...
# 374  [show, me, a, video, from, cineamasin, matchin...
# 375  [show, me, a, videos, published, by, wwe, matc...
# 376  [notify, me, when, there, is, new, video, from...
# 377  [notify, me, when, there, is, new, video, from...
#
# [378 rows x 3 columns]

# %%
col = leyzer_df['intent']
for row in col:
